# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'D:\\Data science\\Python'

# %%
df=pd.read_csv('df.csv')

# %%
df
# Out:
#        price    brand     model  model_year       city  km_driven    fuel  \
# 0     455199     Ford  Ecosport        2014  New Delhi     156349  Diesel
# 1     459999   Maruti    Ertiga        2013  New Delhi     113217  Diesel
# 2     441299     Ford  Ecosport        2014  New Delhi      62984  Diesel
# 3    1272899      BMW        X3        2013  New Delhi      66953  Diesel
# 4     630099  Hyundai       New        2013  New Delhi      48179  Diesel
# ..       ...      ...       ...         ...        ...        ...     ...
# 355   307299  Renault      Kwid        2019      patna      30655  Petrol
# 356   809799    Honda      City        2018      patna      26367  Petrol
# 357   537399    Honda      City        2015      patna      27637  Petrol
# 358   315999  Renault      Kwid        2018      patna      59514  Petrol
# 359   473999   Maruti     Swift        2018      patna      98198  Diesel
#
#     owner    emi
# 0     1st  10126
# 1     1st  10232
# 2     1st   9816
# ...

# %% [markdown]
# # univariate analysis

# %%
df
# Out:
#        price    brand     model  model_year       city  km_driven    fuel  \
# 0     455199     Ford  Ecosport        2014  New Delhi     156349  Diesel
# 1     459999   Maruti    Ertiga        2013  New Delhi     113217  Diesel
# 2     441299     Ford  Ecosport        2014  New Delhi      62984  Diesel
# 3    1272899      BMW        X3        2013  New Delhi      66953  Diesel
# 4     630099  Hyundai       New        2013  New Delhi      48179  Diesel
# ..       ...      ...       ...         ...        ...        ...     ...
# 355   307299  Renault      Kwid        2019      patna      30655  Petrol
# 356   809799    Honda      City        2018      patna      26367  Petrol
# 357   537399    Honda      City        2015      patna      27637  Petrol
# 358   315999  Renault      Kwid        2018      patna      59514  Petrol
# 359   473999   Maruti     Swift        2018      patna      98198  Diesel
#
#     owner    emi
# 0     1st  10126
# 1     1st  10232
# 2     1st   9816
# ...

# %%
df.columns
# Out:
# Index(['price', 'brand', 'model', 'model_year', 'city', 'km_driven', 'fuel',
#        'owner', 'emi'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   price       360 non-null    int64
#  1   brand       360 non-null    object
#  2   model       360 non-null    object
#  3   model_year  360 non-null    int64
#  4   city        360 non-null    object
#  5   km_driven   360 non-null    int64
#  6   fuel        360 non-null    object
#  7   owner       360 non-null    object
#  8   emi         360 non-null    int64
# dtypes: int64(4), object(5)
# memory usage: 25.4+ KB

# %%
df["price"]=df["price"].astype('float')
df['price'].describe()
# Out:
# count    3.600000e+02
# mean     6.657693e+05
# std      3.515274e+05
# min      1.350000e+05
# 25%      4.419740e+05
# 50%      5.707990e+05
# 75%      7.727740e+05
# max      2.529699e+06
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.distplot(df['price'])
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(df['price'])
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %% [markdown]
# we have outlilers in the price after 15 lakhs we have one outlier in 25 lakhs

# %%
df['brand'].describe()
# Out:
# count        360
# unique        19
# top       Maruti
# freq          94
# Name: brand, dtype: object

# %%
df['brand'].value_counts()
# Out:
# Maruti        94
# Hyundai       78
# Honda         37
# Ford          35
# Mahindra      21
# Renault       21
# Toyota        17
# Tata          16
# Volkswagen    12
# Datsun         6
# Audi           4
# Skoda          4
# Mercedes       3
# Nissan         3
# BMW            3
# KIA            3
# Chevrolet      1
# MG             1
# Jeep           1
# Name: brand, dtype: int64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(df['brand'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# the second most avaliable cars are maruti and hyundai and chevrolet as the very less avalibilty

# %%
df['model'].describe()
# Out:
# count          360
# unique          78
# top       Ecosport
# freq            24
# Name: model, dtype: object

# %%
df['model'].value_counts()
# Out:
# Ecosport    24
# Elite       21
# City        16
# Swift       16
# Baleno      15
#             ..
# X3           1
# MAGNITE      1
# Beat         1
# Terrano      1
# Compass      1
# Name: model, Length: 78, dtype: int64

# %%
df['model'].value_counts()[:20]
# Out:
# Ecosport    24
# Elite       21
# City        16
# Swift       16
# Baleno      15
# Kwid        14
# Creta       12
# i20         11
# Alto        11
# Amaze        8
# Dzire        8
# S            7
# Ciaz         7
# TUV300       7
# Vitara       7
# Tiago        6
# Scorpio      6
# Innova       6
# Redi         6
# WR-V         6
# Name: model, dtype: int64

# %%
df['model'].value_counts(normalize = True)
# Out:
# Ecosport    0.066667
# Elite       0.058333
# City        0.044444
# Swift       0.044444
# Baleno      0.041667
#               ...
# X3          0.002778
# MAGNITE     0.002778
# Beat        0.002778
# Terrano     0.002778
# Compass     0.002778
# Name: model, Length: 78, dtype: float64

# %%
plt.figure(figsize=(10,4),dpi=200)
plt.pie(df['model'].value_counts()[:20],labels=df['model'].unique()[:20])
plt.legend(loc=(1.5,0))
plt.show()

# %%
df['model_year']=df['model_year'].astype(float)
df['model_year'].describe()
# Out:
# count     360.000000
# mean     2016.419444
# std         2.429888
# min      2009.000000
# 25%      2015.000000
# 50%      2017.000000
# 75%      2018.000000
# max      2021.000000
# Name: model_year, dtype: float64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.displot(df['model_year'])

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(df['model_year'])
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='model_year'>

# %%
Most of the cars are between 2015 to 2018

# %%
df["city"].describe()
# Out:
# count           360
# unique           18
# top       New Delhi
# freq             20
# Name: city, dtype: object

# %%
df['city'].unique()
# Out:
# array(['New Delhi', 'Noida', 'Gurgaon', 'Mumbai', 'pune', 'Bengaluru',
#        'Hyderabad', 'chennai', 'kolkata', 'Ahmedabad', 'Bhopal',
#        'Chandigarh', 'coimbatore', 'Faridabad ', 'Ghaziabad', 'jaipur',
#        'lucknow', 'patna'], dtype=object)

# %%
plt.figure(figsize=(10,4),dpi=200)
plt.pie(df['city'].value_counts(), labels=df['city'].unique())
plt.legend(loc=(1.5,0))
plt.show()

# %%
df["km_driven"]=df["km_driven"].astype(float)
df["km_driven"].describe()
# Out:
# count       360.000000
# mean      51303.125000
# std       34119.735039
# min         562.000000
# 25%       26688.750000
# 50%       45864.000000
# 75%       69547.250000
# max      225749.000000
# Name: km_driven, dtype: float64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.displot(df['km_driven'])

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.boxplot(df['km_driven'])
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='km_driven'>

# %% [markdown]
# we have outliyers after 130000km so most of the cars driven between 50000 to 100000 km

# %%
df["fuel"].describe()
# Out:
# count        360
# unique         2
# top       Petrol
# freq         233
# Name: fuel, dtype: object

# %%
df['fuel'].value_counts(normalize = True)
# Out:
# Petrol    0.647222
# Diesel    0.352778
# Name: fuel, dtype: float64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(df['fuel'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# in petrol we have more cars

# %%
plt.figure(figsize=(10,4),dpi=200)
plt.pie(df['fuel'].value_counts(), labels=df['fuel'].unique())
plt.legend(loc=(1.5,0))
plt.show()

# %%
df['owner'].describe()
# Out:
# count     360
# unique      4
# top       1st
# freq      275
# Name: owner, dtype: object

# %%
a=df['owner'].value_counts()
a
# Out:
# 1st    275
# 2nd     77
# 3rd      7
# 4th      1
# Name: owner, dtype: int64

# %%
d=pd.DataFrame(a)
d
# Out:
#      owner
# 1st    275
# 2nd     77
# 3rd      7
# 4th      1

# %%
df['owner'].value_counts(normalize = True)
# Out:
# 1st    0.763889
# 2nd    0.213889
# 3rd    0.019444
# 4th    0.002778
# Name: owner, dtype: float64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.countplot(df['owner'])
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,4),dpi=200)
plt.pie(df['owner'].value_counts(), labels=df['owner'].unique())
plt.legend(loc=(1.5,0))
plt.show()

# %% [markdown]
# the 1st owner cars are more compare to 2nd 3rd and 4th

# %%
df['emi']=df['emi'].astype(float)
df['emi'].describe()
# Out:
# count      360.000000
# mean     14809.677778
# std       7819.568395
# min       3003.000000
# 25%       9831.000000
# 50%      12697.000000
# 75%      17189.750000
# max      56272.000000
# Name: emi, dtype: float64

# %%
plt.figure(figsize=(10,4),dpi=200)
sns.displot(df['emi'])
plt.xticks(rotation=90)
plt.show()

# %%
df.describe()
# Out:
#               price   model_year      km_driven           emi
# count  3.600000e+02   360.000000     360.000000    360.000000
# mean   6.657693e+05  2016.419444   51303.125000  14809.677778
# std    3.515274e+05     2.429888   34119.735039   7819.568395
# min    1.350000e+05  2009.000000     562.000000   3003.000000
# 25%    4.419740e+05  2015.000000   26688.750000   9831.000000
# 50%    5.707990e+05  2017.000000   45864.000000  12697.000000
# 75%    7.727740e+05  2018.000000   69547.250000  17189.750000
# max    2.529699e+06  2021.000000  225749.000000  56272.000000

# %%
df["km_driven"].describe()
# Out:
# count       360.000000
# mean      51303.125000
# std       34119.735039
# min         562.000000
# 25%       26688.750000
# 50%       45864.000000
# 75%       69547.250000
# max      225749.000000
# Name: km_driven, dtype: float64

# %% [markdown]
# # Bivariate analysis

# %% [markdown]
# # User Requirements
# 1. Budget 5 to 10 lakhs
# 2. km driven should be less than 50,000
# 3. Deisel vehicle
# 4. City should be Hyderabad
# 5. Model year should be after 2016

# %%
pd.crosstab(df['price'],df['owner'],margins=True)/len(df)
# Out:
# owner           1st       2nd       3rd       4th       All
# price
# 135000.0   0.002778  0.000000  0.000000  0.000000  0.002778
# 213399.0   0.000000  0.002778  0.000000  0.000000  0.002778
# 244099.0   0.000000  0.002778  0.000000  0.000000  0.002778
# 250000.0   0.002778  0.000000  0.000000  0.000000  0.002778
# 272999.0   0.002778  0.000000  0.000000  0.000000  0.002778
# ...             ...       ...       ...       ...       ...
# 1978199.0  0.002778  0.000000  0.000000  0.000000  0.002778
# 2076499.0  0.002778  0.000000  0.000000  0.000000  0.002778
# 2101599.0  0.000000  0.002778  0.000000  0.000000  0.002778
# 2529699.0  0.002778  0.000000  0.000000  0.000000  0.002778
# All        0.763889  0.213889  0.019444  0.002778  1.000000
#
# [352 rows x 5 columns]

# %%
df
# Out:
#          price    brand     model  model_year       city  km_driven    fuel  \
# 0     455199.0     Ford  Ecosport      2014.0  New Delhi   156349.0  Diesel
# 1     459999.0   Maruti    Ertiga      2013.0  New Delhi   113217.0  Diesel
# 2     441299.0     Ford  Ecosport      2014.0  New Delhi    62984.0  Diesel
# 3    1272899.0      BMW        X3      2013.0  New Delhi    66953.0  Diesel
# 4     630099.0  Hyundai       New      2013.0  New Delhi    48179.0  Diesel
# ..         ...      ...       ...         ...        ...        ...     ...
# 355   307299.0  Renault      Kwid      2019.0      patna    30655.0  Petrol
# 356   809799.0    Honda      City      2018.0      patna    26367.0  Petrol
# 357   537399.0    Honda      City      2015.0      patna    27637.0  Petrol
# 358   315999.0  Renault      Kwid      2018.0      patna    59514.0  Petrol
# 359   473999.0   Maruti     Swift      2018.0      patna    98198.0  Diesel
#
#     owner      emi
# 0     1st  10126.0
# ...

# %%
df.groupby(['brand'])['price'].agg({'mean','median'})
# Out:
#                     mean     median
# brand
# Audi        1.343374e+06  1396649.0
# BMW         1.371366e+06  1314799.0
# Chevrolet   2.133990e+05   213399.0
# Datsun      2.910157e+05   288649.0
# Ford        6.668904e+05   538499.0
# Honda       7.167612e+05   709899.0
# Hyundai     6.553516e+05   554299.0
# Jeep        1.447899e+06  1447899.0
# KIA         1.231532e+06  1259399.0
# MG          1.837899e+06  1837899.0
# Mahindra    8.364085e+05   726099.0
# Maruti      5.394479e+05   534949.0
# Mercedes    1.667166e+06  1652399.0
# Nissan      6.649323e+05   496799.0
# Renault     4.163276e+05   384099.0
# Skoda       7.809990e+05   763499.0
# Tata        7.579178e+05   577349.0
# Toyota      8.081578e+05   625599.0
# Volkswagen  6.057907e+05   546999.0

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.boxplot(x=df['brand'], y=df['price'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# in bivariate analysing we analysied which brand 2nd hand car is costly and which car is less price
# so the outliers in frod hyundai is having the less price

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.scatterplot(x=df['model_year'], y=df['price'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Cars after  2015 is more price compare to cars before 2015

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.boxplot(x=df['city'], y=df['price'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.scatterplot(x=df['km_driven'], y=df['price'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.violinplot(x=df['fuel'], y=df['price'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.barplot(x=df['fuel'], y=df['price'])
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13736/412586965.py in <module>
# ----> 1 plt.figure(figsize=(10,4),dpi=250)
#       2 sns.barplot(x=df['fuel'], y=df['price'])
#       3 plt.xticks(rotation=90)
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
df.groupby(['owner'])['price'].agg({'mean','median'})
# Out:
#                 mean    median
# owner
# 1st    676970.283636  595999.0
# 2nd    637914.584416  528999.0
# 3rd    571770.428571  488399.0
# 4th    388299.000000  388299.0

# %%
pd.crosstab(df['price'],df['owner'],margins=True)/len(df)
# Out:
# owner           1st       2nd       3rd       4th       All
# price
# 135000.0   0.002778  0.000000  0.000000  0.000000  0.002778
# 213399.0   0.000000  0.002778  0.000000  0.000000  0.002778
# 244099.0   0.000000  0.002778  0.000000  0.000000  0.002778
# 250000.0   0.002778  0.000000  0.000000  0.000000  0.002778
# 272999.0   0.002778  0.000000  0.000000  0.000000  0.002778
# ...             ...       ...       ...       ...       ...
# 1978199.0  0.002778  0.000000  0.000000  0.000000  0.002778
# 2076499.0  0.002778  0.000000  0.000000  0.000000  0.002778
# 2101599.0  0.000000  0.002778  0.000000  0.000000  0.002778
# 2529699.0  0.002778  0.000000  0.000000  0.000000  0.002778
# All        0.763889  0.213889  0.019444  0.002778  1.000000
#
# [352 rows x 5 columns]

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.barplot(x=df['owner'], y=df['price'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.scatterplot(x=df['emi'], y=df['price'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.scatterplot(x=df['brand'], y=df['model_year'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.scatterplot(x=df['brand'], y=df['km_driven'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.scatterplot(x=df['brand'], y=df['owner'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.barplot(x=df['brand'], y=df['emi'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.violinplot(x=df['owner'], y=df['model_year'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.scatterplot(x=df['city'], y=df['model_year'])
plt.xticks(rotation=90)
plt.show()

# %%
df.groupby(['owner'])['km_driven'].agg({'mean','median'})
# Out:
#                mean   median
# owner
# 1st    49491.385455  43878.0
# 2nd    54621.454545  51271.0
# 3rd    86868.571429  61044.0
# 4th    45062.000000  45062.0

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.barplot(x=df['owner'], y=df['km_driven'])
plt.xticks(rotation=90)
plt.show()

# %%
fst= df[df['owner']=='1st']

# %%
fst
# Out:
#          price    brand     model  model_year       city  km_driven    fuel  \
# 0     455199.0     Ford  Ecosport      2014.0  New Delhi   156349.0  Diesel
# 1     459999.0   Maruti    Ertiga      2013.0  New Delhi   113217.0  Diesel
# 2     441299.0     Ford  Ecosport      2014.0  New Delhi    62984.0  Diesel
# 3    1272899.0      BMW        X3      2013.0  New Delhi    66953.0  Diesel
# 5     855999.0  Hyundai     Creta      2017.0  New Delhi    78200.0  Diesel
# ..         ...      ...       ...         ...        ...        ...     ...
# 355   307299.0  Renault      Kwid      2019.0      patna    30655.0  Petrol
# 356   809799.0    Honda      City      2018.0      patna    26367.0  Petrol
# 357   537399.0    Honda      City      2015.0      patna    27637.0  Petrol
# 358   315999.0  Renault      Kwid      2018.0      patna    59514.0  Petrol
# 359   473999.0   Maruti     Swift      2018.0      patna    98198.0  Diesel
#
#     owner      emi
# 0     1st  10126.0
# ...

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.boxplot(x=fst['brand'], y=fst['price'])
plt.xticks(rotation=90)
plt.show()

# %%
df.groupby(['km_driven'])['price'].agg({'mean','median'})
# Out:
#                 mean     median
# km_driven
# 562.0       575099.0   575099.0
# 1923.0     1213499.0  1213499.0
# 2548.0     1837899.0  1837899.0
# 3880.0      512299.0   512299.0
# 4189.0     1068599.0  1068599.0
# ...              ...        ...
# 167729.0    346499.0   346499.0
# 169294.0    553799.0   553799.0
# 170588.0    537299.0   537299.0
# 214687.0   1394499.0  1394499.0
# 225749.0    468599.0   468599.0
#
# [359 rows x 2 columns]

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.scatterplot(x=fst['km_driven'], y=fst['price'])
plt.xticks(rotation=90)
plt.show()

# %%
df.groupby(['fuel'])['price'].agg({'mean','median'})
# Out:
#                  mean    median
# fuel
# Diesel  823609.236220  667499.0
# Petrol  579736.351931  534399.0

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.barplot(x=fst['fuel'], y=fst['price'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.barplot(x=fst['city'], y=fst['price'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.boxplot(x=fst['model_year'], y=fst['price'])
plt.xticks(rotation=90)
plt.show()

# %%
snd= df[df['owner']=='2nd']

# %%
snd
# Out:
#          price       brand     model  model_year       city  km_driven  \
# 4     630099.0     Hyundai       New      2013.0  New Delhi    48179.0
# 10    907899.0    Mahindra   Scorpio      2017.0  New Delhi    45020.0
# 16    244099.0      Maruti     Wagon      2010.0  New Delhi    48913.0
# 24   1409299.0        Audi        A3      2014.0      Noida    33961.0
# 25   1455599.0    Mercedes      Benz      2013.0      Noida    42881.0
# ..         ...         ...       ...         ...        ...        ...
# 327   575599.0        Tata      Zest      2017.0    lucknow    43927.0
# 337   892099.0       Honda      City      2018.0    lucknow    46904.0
# 338   620399.0        Ford  Ecosport      2017.0    lucknow    29598.0
# 342   404899.0  Volkswagen      Ameo      2017.0      patna    11645.0
# 345   371599.0     Hyundai     Verna      2011.0      patna    58938.0
#
#        fuel owner      emi
# 4    Diesel   2nd  14016.0
# 10   Diesel   2nd  20196.0
# 16   Petrol   2nd   5430.0
# ...

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.boxplot(x=snd['brand'], y=snd['price'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.scatterplot(x=snd['km_driven'], y=snd['price'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.barplot(x=snd['fuel'], y=snd['price'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.barplot(x=snd['city'], y=snd['price'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.boxplot(x=snd['model_year'], y=snd['price'])
plt.xticks(rotation=90)
plt.show()

# %%
rd= df[df['owner']=='3rd']

# %%
rd
# Out:
#          price   brand   model  model_year        city  km_driven    fuel  \
# 100   279299.0  Maruti    Alto      2013.0   Bengaluru    28791.0  Petrol
# 103   404899.0   Honda    Brio      2014.0   Bengaluru    41966.0  Petrol
# 199   535499.0  Maruti       S      2016.0   Ahmedabad    96372.0  Diesel
# 222  1314799.0     BMW       3      2013.0  Chandigarh   153158.0  Diesel
# 234   537299.0  Toyota  Innova      2012.0  Chandigarh   170588.0  Diesel
# 260   442199.0   Honda    City      2013.0  Faridabad     56161.0  Petrol
# 319   488399.0  Maruti  Baleno      2016.0      jaipur    61044.0  Petrol
#
#     owner      emi
# 100   3rd   6213.0
# 103   3rd   9007.0
# 199   3rd  11912.0
# 222   3rd  29247.0
# 234   3rd  11952.0
# 260   3rd   9836.0
# 319   3rd  10864.0

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.boxplot(x=rd['brand'], y=rd['price'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.scatterplot(x=rd['km_driven'], y=rd['price'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.barplot(x=rd['fuel'], y=rd['price'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.barplot(x=rd['city'], y=rd['price'])
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.boxplot(x=rd['model_year'], y=rd['price'])
plt.xticks(rotation=90)
plt.show()

# %%
th= df[df['owner']=='4th']

# %%
th
# Out:
#        price  brand  model  model_year  city  km_driven    fuel owner     emi
# 96  388299.0  Honda  Amaze      2013.0  pune    45062.0  Petrol   4th  8637.0

# %% [markdown]
# # User Requirements
# 1. Budget 5 to 10 lakhs
# 2. km driven should be less than 50,000
# 3. Deisel vehicle
# 4. City should be Hyderabad
# 5. Model year should be after 2016

# %%
df_price=df[(df["price"]>=500000) & (df["price"]<=1000000)]

# %%
df_price
# Out:
#         price     brand     model  model_year       city  km_driven    fuel  \
# 4    630099.0   Hyundai       New      2013.0  New Delhi    48179.0  Diesel
# 5    855999.0   Hyundai     Creta      2017.0  New Delhi    78200.0  Diesel
# 7    541999.0   Hyundai       i20      2015.0  New Delhi    57978.0  Diesel
# 8    509699.0   Hyundai       i20      2015.0  New Delhi    83105.0  Diesel
# 10   907899.0  Mahindra   Scorpio      2017.0  New Delhi    45020.0  Diesel
# ..        ...       ...       ...         ...        ...        ...     ...
# 351  769999.0      Ford  Ecosport      2017.0      patna    35423.0  Diesel
# 352  579099.0      Tata     NEXON      2018.0      patna    38765.0  Petrol
# 354  713299.0  Mahindra    TUV300      2018.0      patna    45427.0  Diesel
# 356  809799.0     Honda      City      2018.0      patna    26367.0  Petrol
# 357  537399.0     Honda      City      2015.0      patna    27637.0  Petrol
#
#     owner      emi
# 4     2nd  14016.0
# ...

# %%
sns.displot(df_price['price'])

# %%
df_km=df_price[df_price['km_driven']<=50000]

# %%
df_km
# Out:
#         price     brand     model  model_year       city  km_driven    fuel  \
# 4    630099.0   Hyundai       New      2013.0  New Delhi    48179.0  Diesel
# 10   907899.0  Mahindra   Scorpio      2017.0  New Delhi    45020.0  Diesel
# 13   602999.0      Tata     NEXON      2018.0  New Delhi    15624.0  Petrol
# 15   734599.0   Renault     Kiger      2021.0  New Delhi     9193.0  Petrol
# 21   542299.0    Maruti     Dzire      2018.0      Noida    14025.0  Petrol
# ..        ...       ...       ...         ...        ...        ...     ...
# 351  769999.0      Ford  Ecosport      2017.0      patna    35423.0  Diesel
# 352  579099.0      Tata     NEXON      2018.0      patna    38765.0  Petrol
# 354  713299.0  Mahindra    TUV300      2018.0      patna    45427.0  Diesel
# 356  809799.0     Honda      City      2018.0      patna    26367.0  Petrol
# 357  537399.0     Honda      City      2015.0      patna    27637.0  Petrol
#
#     owner      emi
# 4     2nd  14016.0
# ...

# %%
sns.displot(df_km['km_driven'])

# %%
plt.figure(figsize=(10,4),dpi=250)
sns.scatterplot(x=df_price['price'], y=df_km['km_driven'])
plt.xticks(rotation=90)
plt.show()

# %%
df_city=df_km[(df_km['city']=='Hyderabad')]

# %%
df_city
# Out:
#         price       brand      model  model_year       city  km_driven  \
# 121  585599.0      Maruti      Swift      2016.0  Hyderabad    46437.0
# 125  604199.0        Ford  FREESTYLE      2018.0  Hyderabad    31886.0
# 133  753499.0       Honda      Amaze      2018.0  Hyderabad    43878.0
# 134  647399.0  Volkswagen       Polo      2019.0  Hyderabad    26690.0
#
#        fuel owner      emi
# 121  Petrol   2nd  13026.0
# 125  Petrol   2nd  13440.0
# 133  Diesel   1st  16761.0
# 134  Petrol   1st  14401.0

# %%
df_fuel=df_city[(df_city['fuel']=='Diesel')]

# %%
df_fuel
# Out:
#         price  brand  model  model_year       city  km_driven    fuel owner  \
# 133  753499.0  Honda  Amaze      2018.0  Hyderabad    43878.0  Diesel   1st
#
#          emi
# 133  16761.0

# %% [markdown]
# # User Requirements
# 1. Budget 5L
# 2. km driven should be less than 100000
# 3. petrol vehicle
# 4. City should be Hyderabad
# 5. Model year should be after 2017

# %%
df1_price=df[(df["price"]<=500000)]

# %%
df1_price
# Out:
#         price    brand     model  model_year       city  km_driven    fuel  \
# 0    455199.0     Ford  Ecosport      2014.0  New Delhi   156349.0  Diesel
# 1    459999.0   Maruti    Ertiga      2013.0  New Delhi   113217.0  Diesel
# 2    441299.0     Ford  Ecosport      2014.0  New Delhi    62984.0  Diesel
# 6    482099.0   Nissan   Terrano      2014.0  New Delhi    51899.0  Diesel
# 9    314299.0   Toyota     Etios      2011.0  New Delhi    85899.0  Petrol
# ..        ...      ...       ...         ...        ...        ...     ...
# 349  405799.0   Toyota     Etios      2016.0      patna    84886.0  Diesel
# 350  322799.0    Honda     Amaze      2013.0      patna    83206.0  Petrol
# 355  307299.0  Renault      Kwid      2019.0      patna    30655.0  Petrol
# 358  315999.0  Renault      Kwid      2018.0      patna    59514.0  Petrol
# 359  473999.0   Maruti     Swift      2018.0      patna    98198.0  Diesel
#
#     owner      emi
# 0     1st  10126.0
# 1     1st  10232.0
# ...

# %%
sns.displot(df1_price['price'])

# %%
df1_km=df1_price[df1_price['km_driven']<=100000]

# %%
df1_km
# Out:
#         price    brand     model  model_year       city  km_driven    fuel  \
# 2    441299.0     Ford  Ecosport      2014.0  New Delhi    62984.0  Diesel
# 6    482099.0   Nissan   Terrano      2014.0  New Delhi    51899.0  Diesel
# 9    314299.0   Toyota     Etios      2011.0  New Delhi    85899.0  Petrol
# 16   244099.0   Maruti     Wagon      2010.0  New Delhi    48913.0  Petrol
# 20   323699.0   Maruti      Alto      2018.0      Noida    41533.0  Petrol
# ..        ...      ...       ...         ...        ...        ...     ...
# 349  405799.0   Toyota     Etios      2016.0      patna    84886.0  Diesel
# 350  322799.0    Honda     Amaze      2013.0      patna    83206.0  Petrol
# 355  307299.0  Renault      Kwid      2019.0      patna    30655.0  Petrol
# 358  315999.0  Renault      Kwid      2018.0      patna    59514.0  Petrol
# 359  473999.0   Maruti     Swift      2018.0      patna    98198.0  Diesel
#
#     owner      emi
# 2     1st   9816.0
# 6     1st  10724.0
# ...

# %%
sns.displot(df_km['km_driven'])

# %%
df1_city=df1_km[(df1_km['city']=='Hyderabad')]

# %%
df1_city
# Out:
#         price    brand  model  model_year       city  km_driven    fuel owner  \
# 129  333899.0  Renault   Kwid      2016.0  Hyderabad    56000.0  Petrol   1st
# 131  462399.0    Honda  Amaze      2014.0  Hyderabad    31743.0  Petrol   1st
# 139  442599.0     Tata  Tiago      2017.0  Hyderabad     6757.0  Petrol   1st
#
#          emi
# 129   7427.0
# 131  10286.0
# 139   9845.0

# %%
df1_fuel=df1_city[(df1_city['fuel']=='Petrol')]

# %%
df1_fuel
# Out:
#         price    brand  model  model_year       city  km_driven    fuel owner  \
# 129  333899.0  Renault   Kwid      2016.0  Hyderabad    56000.0  Petrol   1st
# 131  462399.0    Honda  Amaze      2014.0  Hyderabad    31743.0  Petrol   1st
# 139  442599.0     Tata  Tiago      2017.0  Hyderabad     6757.0  Petrol   1st
#
#          emi
# 129   7427.0
# 131  10286.0
# 139   9845.0

# %%
pd.crosstab(df['price'],df['owner'],margins=True)/len(df)
# Out:
# owner           1st       2nd       3rd       4th       All
# price
# 135000.0   0.002778  0.000000  0.000000  0.000000  0.002778
# 213399.0   0.000000  0.002778  0.000000  0.000000  0.002778
# 244099.0   0.000000  0.002778  0.000000  0.000000  0.002778
# 250000.0   0.002778  0.000000  0.000000  0.000000  0.002778
# 272999.0   0.002778  0.000000  0.000000  0.000000  0.002778
# ...             ...       ...       ...       ...       ...
# 1978199.0  0.002778  0.000000  0.000000  0.000000  0.002778
# 2076499.0  0.002778  0.000000  0.000000  0.000000  0.002778
# 2101599.0  0.000000  0.002778  0.000000  0.000000  0.002778
# 2529699.0  0.002778  0.000000  0.000000  0.000000  0.002778
# All        0.763889  0.213889  0.019444  0.002778  1.000000
#
# [352 rows x 5 columns]

# %%
df[['price','km_driven','emi','model_year']].corr()
# Out:
#                price  km_driven       emi  model_year
# price       1.000000  -0.114114  1.000000    0.316465
# km_driven  -0.114114   1.000000 -0.114113   -0.508326
# emi         1.000000  -0.114113  1.000000    0.316466
# model_year  0.316465  -0.508326  0.316466    1.000000

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(fst.corr(), annot=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(snd.corr(), annot=True)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(rd.corr(), annot=True)
plt.show()
